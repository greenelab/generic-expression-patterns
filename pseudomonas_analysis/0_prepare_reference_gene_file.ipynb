# %% [markdown]
# # Prepare reference gene file
#
# This notebook creates a reference gene ranking file to use to compare SOPHIE generated gene ranking. The reference ranking information is obtained from [this repository](https://github.com/DartmouthStantonLab/GAPE). This [RDS object](https://github.com/DartmouthStantonLab/GAPE/blob/main/Pa_GPL84_refine_ANOVA_List_unzip.rds) contains 73 experiments. For each experiment, we will identify DEGs using log2FC > 1 and FDR < 0.05. We will rank genes by the proportion that they appeared as DE.

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext rpy2.ipython

import os
import pandas as pd
import rpy2.robjects as ro
from rpy2.robjects import pandas2ri
from rpy2.robjects.conversion import localconverter

from ponyo import utils

pandas2ri.activate()

# %%
# Read in config variables
base_dir = os.path.abspath(os.path.join(os.getcwd(), "../"))

config_filename = os.path.abspath(
    os.path.join(base_dir, "configs", "config_pseudomonas_33245.tsv")
)
params = utils.read_config(config_filename)

# %%
# Load params
local_dir = params["local_dir"]
reference_gene_filename = os.path.join(
    local_dir, "Pa_GPL84_refine_ANOVA_List_unzip.rds"
)

# %%
readRDS = ro.r["readRDS"]

# %%
reference_Robject = readRDS(reference_gene_filename)

# %%
# For each experiment get df
# For each df, if label gene as DEGs based on log2FC>1 and FDR<0.05
# Concatenate series
num_experiments = len(reference_Robject)
reference_stats_df = pd.DataFrame()

for i in range(num_experiments):
    print(i)
    # Get df for experiment
    reference_df = ro.conversion.rpy2py(reference_Robject[i])

    reference_df = reference_df.set_index("ProbeID")
    print(reference_df.head())

    # Find DEGs
    degs_ids = list(
        reference_df[
            (abs(reference_df["Log2FC"]) > 1) & (reference_df["FDR"] < 0.05)
        ].index
    )
    reference_df["DEG"] = 0
    reference_df.loc[degs_ids, "DEG"] = 1
    print(reference_df.head())

    # Create df with labels for if gene is DE or not
    if i == 0:
        reference_stats_df = reference_df["DEG"].to_frame("experiment_0")
    else:
        reference_stats_df = pd.merge(
            reference_stats_df,
            reference_df["DEG"].to_frame(f"experiment_{i}"),
            left_index=True,
            right_index=True,
            how="left",
        )
reference_stats_df
# Out:
# 0
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.925179
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.390903
# AFFX-Athal_ubq_at                             --control     0.098989
# AFFX-Bsubtilis_dapB_at                        --control     0.000146
# AFFX-Bsubtilis_lys_at                         --control     0.031852
#
#                           Log2FC       FDR
# ProbeID
# AFFX-Athal_actin_at     0.738742  0.943785
# AFFX-Athal_GAPDH_at     2.701846  0.481086
# AFFX-Athal_ubq_at       3.967257  0.165215
# AFFX-Bsubtilis_dapB_at  9.487297  0.001595
# AFFX-Bsubtilis_lys_at   2.640334  0.068913
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.925179
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.390903
# AFFX-Athal_ubq_at                             --control     0.098989
# AFFX-Bsubtilis_dapB_at                        --control     0.000146
# AFFX-Bsubtilis_lys_at                         --control     0.031852
#
#                           Log2FC       FDR  DEG
# ProbeID
# AFFX-Athal_actin_at     0.738742  0.943785    0
# AFFX-Athal_GAPDH_at     2.701846  0.481086    0
# AFFX-Athal_ubq_at       3.967257  0.165215    0
# AFFX-Bsubtilis_dapB_at  9.487297  0.001595    1
# AFFX-Bsubtilis_lys_at   2.640334  0.068913    0
# 1
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.365395
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.013522
# AFFX-Athal_ubq_at                             --control     0.776123
# AFFX-Bsubtilis_dapB_at                        --control     0.940183
# AFFX-Bsubtilis_lys_at                         --control     0.313617
#
#                           Log2FC       FDR
# ProbeID
# AFFX-Athal_actin_at     2.602396  0.525941
# AFFX-Athal_GAPDH_at     2.556803  0.121857
# AFFX-Athal_ubq_at       1.268012  0.839397
# AFFX-Bsubtilis_dapB_at  0.619006  0.959536
# AFFX-Bsubtilis_lys_at   3.426617  0.482574
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.365395
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.013522
# AFFX-Athal_ubq_at                             --control     0.776123
# AFFX-Bsubtilis_dapB_at                        --control     0.940183
# AFFX-Bsubtilis_lys_at                         --control     0.313617
#
#                           Log2FC       FDR  DEG
# ProbeID
# AFFX-Athal_actin_at     2.602396  0.525941    0
# AFFX-Athal_GAPDH_at     2.556803  0.121857    0
# AFFX-Athal_ubq_at       1.268012  0.839397    0
# AFFX-Bsubtilis_dapB_at  0.619006  0.959536    0
# AFFX-Bsubtilis_lys_at   3.426617  0.482574    0
# 2
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.065556
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.221065
# AFFX-Athal_ubq_at                             --control     0.055260
# AFFX-Bsubtilis_dapB_at                        --control     0.001432
# AFFX-Bsubtilis_lys_at                         --control     0.000191
#
#                           Log2FC       FDR
# ProbeID
# AFFX-Athal_actin_at     0.120837  0.083304
# AFFX-Athal_GAPDH_at     0.070455  0.240599
# AFFX-Athal_ubq_at       0.111014  0.071908
# AFFX-Bsubtilis_dapB_at  2.414170  0.004669
# AFFX-Bsubtilis_lys_at   1.721754  0.001237
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.065556
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.221065
# AFFX-Athal_ubq_at                             --control     0.055260
# AFFX-Bsubtilis_dapB_at                        --control     0.001432
# AFFX-Bsubtilis_lys_at                         --control     0.000191
#
#                           Log2FC       FDR  DEG
# ProbeID
# AFFX-Athal_actin_at     0.120837  0.083304    0
# AFFX-Athal_GAPDH_at     0.070455  0.240599    0
# AFFX-Athal_ubq_at       0.111014  0.071908    0
# AFFX-Bsubtilis_dapB_at  2.414170  0.004669    1
# AFFX-Bsubtilis_lys_at   1.721754  0.001237    1
# 3
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.691582
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.835736
# AFFX-Athal_ubq_at                             --control     0.910003
# AFFX-Bsubtilis_dapB_at                        --control     0.060899
# AFFX-Bsubtilis_lys_at                         --control     0.331723
#
#                           Log2FC       FDR
# ProbeID
# AFFX-Athal_actin_at     0.028445  0.736124
# AFFX-Athal_GAPDH_at     0.021945  0.859799
# AFFX-Athal_ubq_at       0.023250  0.923464
# AFFX-Bsubtilis_dapB_at  0.112245  0.105772
# AFFX-Bsubtilis_lys_at   0.061897  0.412035
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.691582
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.835736
# AFFX-Athal_ubq_at                             --control     0.910003
# AFFX-Bsubtilis_dapB_at                        --control     0.060899
# AFFX-Bsubtilis_lys_at                         --control     0.331723
#
#                           Log2FC       FDR  DEG
# ProbeID
# AFFX-Athal_actin_at     0.028445  0.736124    0
# AFFX-Athal_GAPDH_at     0.021945  0.859799    0
# AFFX-Athal_ubq_at       0.023250  0.923464    0
# AFFX-Bsubtilis_dapB_at  0.112245  0.105772    0
# AFFX-Bsubtilis_lys_at   0.061897  0.412035    0
# 4
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.073544
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.766994
# AFFX-Athal_ubq_at                             --control     0.196759
# AFFX-Bsubtilis_dapB_at                        --control     0.556603
# AFFX-Bsubtilis_lys_at                         --control     0.976359
#
#                           Log2FC       FDR
# ProbeID
# AFFX-Athal_actin_at     3.379003  0.263077
# AFFX-Athal_GAPDH_at     1.236768  0.848224
# AFFX-Athal_ubq_at       3.673145  0.406006
# AFFX-Bsubtilis_dapB_at  0.291594  0.703053
# AFFX-Bsubtilis_lys_at   0.061423  0.986897
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.073544
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.766994
# AFFX-Athal_ubq_at                             --control     0.196759
# AFFX-Bsubtilis_dapB_at                        --control     0.556603
# AFFX-Bsubtilis_lys_at                         --control     0.976359
#
#                           Log2FC       FDR  DEG
# ProbeID
# AFFX-Athal_actin_at     3.379003  0.263077    0
# AFFX-Athal_GAPDH_at     1.236768  0.848224    0
# AFFX-Athal_ubq_at       3.673145  0.406006    0
# AFFX-Bsubtilis_dapB_at  0.291594  0.703053    0
# AFFX-Bsubtilis_lys_at   0.061423  0.986897    0
# 5
#                        GeneTitle Symbol LocusTag IntergenicSpotID  \
# ProbeID
# AFFX-Athal_ubq_at                                       --control
# AFFX-Bsubtilis_dapB_at                                  --control
# AFFX-Bsubtilis_lys_at                                   --control
# AFFX-Bsubtilis_pheB_at                                  --control
# AFFX-Bsubtilis_thrC_at                                  --control
#
#                         ANOVAPvalue    Log2FC       FDR
# ProbeID
# AFFX-Athal_ubq_at          0.481135  1.021866  0.684011
# AFFX-Bsubtilis_dapB_at     0.940754  0.172686  0.969441
# AFFX-Bsubtilis_lys_at      0.834419  0.656550  0.909095
# AFFX-Bsubtilis_pheB_at     0.860693  0.225344  0.925010
# AFFX-Bsubtilis_thrC_at     0.578503  0.199556  0.751065
#                        GeneTitle Symbol LocusTag IntergenicSpotID  \
# ProbeID
# AFFX-Athal_ubq_at                                       --control
# AFFX-Bsubtilis_dapB_at                                  --control
# AFFX-Bsubtilis_lys_at                                   --control
# AFFX-Bsubtilis_pheB_at                                  --control
# AFFX-Bsubtilis_thrC_at                                  --control
#
#                         ANOVAPvalue    Log2FC       FDR  DEG
# ProbeID
# AFFX-Athal_ubq_at          0.481135  1.021866  0.684011    0
# AFFX-Bsubtilis_dapB_at     0.940754  0.172686  0.969441    0
# AFFX-Bsubtilis_lys_at      0.834419  0.656550  0.909095    0
# AFFX-Bsubtilis_pheB_at     0.860693  0.225344  0.925010    0
# AFFX-Bsubtilis_thrC_at     0.578503  0.199556  0.751065    0
# 6
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.002260
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.004808
# AFFX-Athal_ubq_at                             --control     0.002127
# AFFX-Bsubtilis_dapB_at                        --control     0.000399
# AFFX-Bsubtilis_lys_at                         --control     0.006750
#
#                           Log2FC       FDR
# ProbeID
# AFFX-Athal_actin_at     0.308709  0.003451
# AFFX-Athal_GAPDH_at     0.271067  0.006647
# AFFX-Athal_ubq_at       0.342913  0.003283
# AFFX-Bsubtilis_dapB_at  0.370110  0.000813
# AFFX-Bsubtilis_lys_at   0.268605  0.008954
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.002260
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.004808
# AFFX-Athal_ubq_at                             --control     0.002127
# AFFX-Bsubtilis_dapB_at                        --control     0.000399
# AFFX-Bsubtilis_lys_at                         --control     0.006750
#
#                           Log2FC       FDR  DEG
# ProbeID
# AFFX-Athal_actin_at     0.308709  0.003451    0
# AFFX-Athal_GAPDH_at     0.271067  0.006647    0
# AFFX-Athal_ubq_at       0.342913  0.003283    0
# AFFX-Bsubtilis_dapB_at  0.370110  0.000813    0
# AFFX-Bsubtilis_lys_at   0.268605  0.008954    0
# 7
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.071010
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.604158
# AFFX-Athal_ubq_at                             --control     0.192904
# AFFX-Bsubtilis_dapB_at                        --control     0.327454
# AFFX-Bsubtilis_lys_at                         --control     0.913474
#
#                           Log2FC       FDR
# ProbeID
# AFFX-Athal_actin_at     1.861654  0.195055
# AFFX-Athal_GAPDH_at     0.528321  0.633726
# AFFX-Athal_ubq_at       1.803130  0.267217
# AFFX-Bsubtilis_dapB_at  0.415088  0.384587
# AFFX-Bsubtilis_lys_at   0.312066  0.918778
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.071010
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.604158
# AFFX-Athal_ubq_at                             --control     0.192904
# AFFX-Bsubtilis_dapB_at                        --control     0.327454
# AFFX-Bsubtilis_lys_at                         --control     0.913474
#
#                           Log2FC       FDR  DEG
# ProbeID
# AFFX-Athal_actin_at     1.861654  0.195055    0
# AFFX-Athal_GAPDH_at     0.528321  0.633726    0
# AFFX-Athal_ubq_at       1.803130  0.267217    0
# AFFX-Bsubtilis_dapB_at  0.415088  0.384587    0
# AFFX-Bsubtilis_lys_at   0.312066  0.918778    0
# 8
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.104013
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.072664
# AFFX-Athal_ubq_at                             --control     0.011347
# AFFX-Bsubtilis_dapB_at                        --control     0.094418
# AFFX-Bsubtilis_lys_at                         --control     0.025519
#
#                           Log2FC       FDR
# ProbeID
# AFFX-Athal_actin_at     3.798336  0.131211
# AFFX-Athal_GAPDH_at     4.414035  0.096320
# AFFX-Athal_ubq_at       3.891290  0.019883
# AFFX-Bsubtilis_dapB_at  2.701364  0.120682
# AFFX-Bsubtilis_lys_at   4.107789  0.039517
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.104013
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.072664
# AFFX-Athal_ubq_at                             --control     0.011347
# AFFX-Bsubtilis_dapB_at                        --control     0.094418
# AFFX-Bsubtilis_lys_at                         --control     0.025519
#
#                           Log2FC       FDR  DEG
# ProbeID
# AFFX-Athal_actin_at     3.798336  0.131211    0
# AFFX-Athal_GAPDH_at     4.414035  0.096320    0
# AFFX-Athal_ubq_at       3.891290  0.019883    1
# AFFX-Bsubtilis_dapB_at  2.701364  0.120682    0
# AFFX-Bsubtilis_lys_at   4.107789  0.039517    1
# 9
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.895359
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.704117
# AFFX-Athal_ubq_at                             --control     0.451224
# AFFX-Bsubtilis_dapB_at                        --control     0.531837
# AFFX-Bsubtilis_lys_at                         --control     0.496524
#
#                           Log2FC       FDR
# ProbeID
# AFFX-Athal_actin_at     1.984813  0.911601
# AFFX-Athal_GAPDH_at     2.123964  0.753612
# AFFX-Athal_ubq_at       2.446542  0.536888
# AFFX-Bsubtilis_dapB_at  0.563781  0.606892
# AFFX-Bsubtilis_lys_at   0.834918  0.575550
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.895359
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.704117
# AFFX-Athal_ubq_at                             --control     0.451224
# AFFX-Bsubtilis_dapB_at                        --control     0.531837
# AFFX-Bsubtilis_lys_at                         --control     0.496524
#
#                           Log2FC       FDR  DEG
# ProbeID
# AFFX-Athal_actin_at     1.984813  0.911601    0
# AFFX-Athal_GAPDH_at     2.123964  0.753612    0
# AFFX-Athal_ubq_at       2.446542  0.536888    0
# AFFX-Bsubtilis_dapB_at  0.563781  0.606892    0
# AFFX-Bsubtilis_lys_at   0.834918  0.575550    0
# 10
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.012258
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.001709
# AFFX-Athal_ubq_at                             --control     0.024282
# AFFX-Bsubtilis_dapB_at                        --control     0.004839
# AFFX-Bsubtilis_lys_at                         --control     0.004979
#
#                           Log2FC       FDR
# ProbeID
# AFFX-Athal_actin_at     1.950618  0.050221
# AFFX-Athal_GAPDH_at     1.677002  0.025678
# AFFX-Athal_ubq_at       1.863875  0.068631
# AFFX-Bsubtilis_dapB_at  1.729741  0.035332
# AFFX-Bsubtilis_lys_at   1.822455  0.035524
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.012258
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.001709
# AFFX-Athal_ubq_at                             --control     0.024282
# AFFX-Bsubtilis_dapB_at                        --control     0.004839
# AFFX-Bsubtilis_lys_at                         --control     0.004979
#
#                           Log2FC       FDR  DEG
# ProbeID
# AFFX-Athal_actin_at     1.950618  0.050221    0
# AFFX-Athal_GAPDH_at     1.677002  0.025678    1
# AFFX-Athal_ubq_at       1.863875  0.068631    0
# AFFX-Bsubtilis_dapB_at  1.729741  0.035332    1
# AFFX-Bsubtilis_lys_at   1.822455  0.035524    1
# 11
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.168929
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.018473
# AFFX-Athal_ubq_at                             --control     0.035101
# AFFX-Bsubtilis_dapB_at                        --control     0.001293
# AFFX-Bsubtilis_lys_at                         --control     0.000014
#
#                           Log2FC       FDR
# ProbeID
# AFFX-Athal_actin_at     5.111042  0.195007
# AFFX-Athal_GAPDH_at     1.293388  0.030658
# AFFX-Athal_ubq_at       2.007597  0.051645
# AFFX-Bsubtilis_dapB_at  2.604050  0.004869
# AFFX-Bsubtilis_lys_at   2.387960  0.000605
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.168929
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.018473
# AFFX-Athal_ubq_at                             --control     0.035101
# AFFX-Bsubtilis_dapB_at                        --control     0.001293
# AFFX-Bsubtilis_lys_at                         --control     0.000014
#
#                           Log2FC       FDR  DEG
# ProbeID
# AFFX-Athal_actin_at     5.111042  0.195007    0
# AFFX-Athal_GAPDH_at     1.293388  0.030658    1
# AFFX-Athal_ubq_at       2.007597  0.051645    0
# AFFX-Bsubtilis_dapB_at  2.604050  0.004869    1
# AFFX-Bsubtilis_lys_at   2.387960  0.000605    1
# 12
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.285543
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.005211
# AFFX-Athal_ubq_at                             --control     0.825658
# AFFX-Bsubtilis_dapB_at                        --control     0.645171
# AFFX-Bsubtilis_lys_at                         --control     0.827207
#
#                           Log2FC       FDR
# ProbeID
# AFFX-Athal_actin_at     0.094728  0.380551
# AFFX-Athal_GAPDH_at     0.097153  0.014633
# AFFX-Athal_ubq_at       0.112484  0.865870
# AFFX-Bsubtilis_dapB_at  0.142606  0.716587
# AFFX-Bsubtilis_lys_at   0.090552  0.867186
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.285543
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.005211
# AFFX-Athal_ubq_at                             --control     0.825658
# AFFX-Bsubtilis_dapB_at                        --control     0.645171
# AFFX-Bsubtilis_lys_at                         --control     0.827207
#
#                           Log2FC       FDR  DEG
# ProbeID
# AFFX-Athal_actin_at     0.094728  0.380551    0
# AFFX-Athal_GAPDH_at     0.097153  0.014633    0
# AFFX-Athal_ubq_at       0.112484  0.865870    0
# AFFX-Bsubtilis_dapB_at  0.142606  0.716587    0
# AFFX-Bsubtilis_lys_at   0.090552  0.867186    0
# 13
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.737790
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.737964
# AFFX-Athal_ubq_at                             --control     0.594757
# AFFX-Bsubtilis_dapB_at                        --control     0.258264
# AFFX-Bsubtilis_lys_at                         --control     0.294578
#
#                           Log2FC       FDR
# ProbeID
# AFFX-Athal_actin_at     0.761619  0.840946
# AFFX-Athal_GAPDH_at     0.728740  0.840946
# AFFX-Athal_ubq_at       0.896521  0.746978
# AFFX-Bsubtilis_dapB_at  0.650216  0.463430
# AFFX-Bsubtilis_lys_at   0.675460  0.497427
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.737790
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.737964
# AFFX-Athal_ubq_at                             --control     0.594757
# AFFX-Bsubtilis_dapB_at                        --control     0.258264
# AFFX-Bsubtilis_lys_at                         --control     0.294578
#
#                           Log2FC       FDR  DEG
# ProbeID
# AFFX-Athal_actin_at     0.761619  0.840946    0
# AFFX-Athal_GAPDH_at     0.728740  0.840946    0
# AFFX-Athal_ubq_at       0.896521  0.746978    0
# AFFX-Bsubtilis_dapB_at  0.650216  0.463430    0
# AFFX-Bsubtilis_lys_at   0.675460  0.497427    0
# 14
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.349333
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.540674
# AFFX-Athal_ubq_at                             --control     0.009620
# AFFX-Bsubtilis_dapB_at                        --control     0.140366
# AFFX-Bsubtilis_lys_at                         --control     0.280044
#
#                           Log2FC       FDR
# ProbeID
# AFFX-Athal_actin_at     2.230858  0.467574
# AFFX-Athal_GAPDH_at     1.188612  0.650351
# AFFX-Athal_ubq_at       3.585612  0.043344
# AFFX-Bsubtilis_dapB_at  1.096997  0.242293
# AFFX-Bsubtilis_lys_at   0.864455  0.395561
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID  ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control     0.349333
# AFFX-Athal_GAPDH_at     GAPC1                 --control     0.540674
# AFFX-Athal_ubq_at                             --control     0.009620
# AFFX-Bsubtilis_dapB_at                        --control     0.140366
# AFFX-Bsubtilis_lys_at                         --control     0.280044
#
#                           Log2FC       FDR  DEG
# ProbeID
# AFFX-Athal_actin_at     2.230858  0.467574    0
# AFFX-Athal_GAPDH_at     1.188612  0.650351    0
# AFFX-Athal_ubq_at       3.585612  0.043344    1
# AFFX-Bsubtilis_dapB_at  1.096997  0.242293    0
# AFFX-Bsubtilis_lys_at   0.864455  0.395561    0
# 15
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID   ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control  6.315618e-18
# AFFX-Athal_GAPDH_at     GAPC1                 --control  1.719300e-17
# AFFX-Athal_ubq_at                             --control  7.194966e-18
# AFFX-Bsubtilis_dapB_at                        --control  2.160318e-01
# AFFX-Bsubtilis_lys_at                         --control  6.971939e-07
#
#                           Log2FC           FDR
# ProbeID
# AFFX-Athal_actin_at     4.459704  1.330791e-15
# AFFX-Athal_GAPDH_at     4.459452  3.169959e-15
# AFFX-Athal_ubq_at       4.468894  1.463803e-15
# AFFX-Bsubtilis_dapB_at  1.584751  2.285026e-01
# AFFX-Bsubtilis_lys_at   4.325189  1.105765e-05
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID   ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control  6.315618e-18
# AFFX-Athal_GAPDH_at     GAPC1                 --control  1.719300e-17
# AFFX-Athal_ubq_at                             --control  7.194966e-18
# AFFX-Bsubtilis_dapB_at                        --control  2.160318e-01
# AFFX-Bsubtilis_lys_at                         --control  6.971939e-07
#
#                           Log2FC           FDR  DEG
# ProbeID
# AFFX-Athal_actin_at     4.459704  1.330791e-15    1
# AFFX-Athal_GAPDH_at     4.459452  3.169959e-15    1
# AFFX-Athal_ubq_at       4.468894  1.463803e-15    1
# AFFX-Bsubtilis_dapB_at  1.584751  2.285026e-01    0
# AFFX-Bsubtilis_lys_at   4.325189  1.105765e-05    1
# 16
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID   ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control  5.596473e-09
# AFFX-Athal_GAPDH_at     GAPC1                 --control  6.662417e-06
# AFFX-Athal_ubq_at                             --control  4.294044e-05
# AFFX-Bsubtilis_dapB_at                        --control  6.675527e-08
# AFFX-Bsubtilis_lys_at                         --control  1.071836e-05
#
#                           Log2FC           FDR
# ProbeID
# AFFX-Athal_actin_at     2.599907  4.450026e-08
# AFFX-Athal_GAPDH_at     2.004904  1.869152e-05
# AFFX-Athal_ubq_at       1.805206  9.708932e-05
# AFFX-Bsubtilis_dapB_at  2.235525  3.583768e-07
# AFFX-Bsubtilis_lys_at   2.320856  2.830722e-05
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID   ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control  5.596473e-09
# AFFX-Athal_GAPDH_at     GAPC1                 --control  6.662417e-06
# AFFX-Athal_ubq_at                             --control  4.294044e-05
# AFFX-Bsubtilis_dapB_at                        --control  6.675527e-08
# AFFX-Bsubtilis_lys_at                         --control  1.071836e-05
#
#                           Log2FC           FDR  DEG
# ProbeID
# AFFX-Athal_actin_at     2.599907  4.450026e-08    1
# AFFX-Athal_GAPDH_at     2.004904  1.869152e-05    1
# AFFX-Athal_ubq_at       1.805206  9.708932e-05    1
# AFFX-Bsubtilis_dapB_at  2.235525  3.583768e-07    1
# AFFX-Bsubtilis_lys_at   2.320856  2.830722e-05    1
# 17
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
#                        Symbol LocusTag IntergenicSpotID   ANOVAPvalue  \
# ProbeID
# AFFX-Athal_actin_at      ACT7                 --control  9.626111e-02
# AFFX-Athal_GAPDH_at     GAPC1                 --control  7.905644e-01
# AFFX-Athal_ubq_at                             --control  7.152093e-01
# AFFX-Bsubtilis_dapB_at                        --control  2.330897e-09
# AFFX-Bsubtilis_lys_at                         --control  1.234445e-08
#
#                            Log2FC       FDR
# ProbeID
# AFFX-Athal_actin_at      3.365388  0.099516
# AFFX-Athal_GAPDH_at      2.242861  0.792714
# AFFX-Athal_ubq_at        1.655403  0.718008
# AFFX-Bsubtilis_dapB_at  11.237837  0.000003
# AFFX-Bsubtilis_lys_at    7.997186  0.000006
#                                                                 GeneTitle  \
# ProbeID
# AFFX-Athal_actin_at                                               actin 7
# AFFX-Athal_GAPDH_at     glyceraldehyde-3-phosphate dehydrogenase C sub...
# AFFX-Athal_ubq_at
# AFFX-Bsubtilis_dapB_at
# AFFX-Bsubtilis_lys_at
#
# ...
# PA0011_at                        1.0      ...                    0
# PA0012_at                        1.0      ...                    0
# PA0013_at                        1.0      ...                    0
# PA0014_at                        0.0      ...                    0
# PA0015_at                        1.0      ...                    0
# PA0016_trkA_at                   1.0      ...                    0
# ...                              ...      ...                  ...
# ig_5991130_5992382_at            1.0      ...                    0
# ig_5992382_5991130_at            0.0      ...                    0
# ig_6090705_6092045_at            0.0      ...                    0
# ig_6092045_6090705_at            1.0      ...                    0
# ig_6125079_6125795_at            1.0      ...                    0
# ig_6125795_6125079_at            0.0      ...                    0
# ig_629884_630527_at              0.0      ...                    0
# ig_630527_629884_at              1.0      ...                    0
# ig_64729_65339_at                0.0      ...                    0
# ig_65339_64729_at                0.0      ...                    0
# ig_65479_66303_at                0.0      ...                    0
# ig_66303_65479_at                0.0      ...                    0
# ig_68616_69272_at                0.0      ...                    0
# ig_69272_68616_at                0.0      ...                    0
# ig_721556_727608_s_at            1.0      ...                    0
# ig_727608_721556_s_at            0.0      ...                    0
# ig_773696_774416_at              0.0      ...                    0
# ig_774416_773696_at              0.0      ...                    0
# ig_785174_785969_at              0.0      ...                    0
# ig_785969_785174_at              0.0      ...                    0
# ig_788253_789144_at              1.0      ...                    0
# ig_789144_788253_at              0.0      ...                    0
# ig_863300_864095_at              1.0      ...                    0
# ig_864095_863300_at              0.0      ...                    0
# ig_884172_884799_at              0.0      ...                    0
# ig_884799_884172_at              0.0      ...                    0
# ig_901046_901934_at              0.0      ...                    0
# ig_901934_901046_at              0.0      ...                    0
# ig_991198_991830_at              1.0      ...                    0
# ig_991830_991198_at              0.0      ...                    0
#
#                         experiment_64  experiment_65  experiment_66  \
# ProbeID
# AFFX-Athal_GAPDH_at               NaN            NaN            NaN
# AFFX-Athal_actin_at               NaN            NaN            NaN
# AFFX-Athal_ubq_at                 NaN            NaN            NaN
# AFFX-Bsubtilis_dapB_at            NaN            NaN            NaN
# AFFX-Bsubtilis_lys_at             NaN            NaN            NaN
# AFFX-Bsubtilis_pheB_at            NaN            NaN            NaN
# AFFX-Bsubtilis_thrC_at            NaN            NaN            NaN
# AFFX-Bsubtilis_trpD_at            NaN            NaN            NaN
# AFFX-YEL002C_WPB1_at              NaN            NaN            NaN
# AFFX-YEL018W_at                   NaN            NaN            NaN
# AFFX-YEL024W_RIP1_at              NaN            NaN            NaN
# AFFX-YER022W_SRB4_at              NaN            NaN            NaN
# AFFX-YER148W_SPT15_at             NaN            NaN            NaN
# AFFX-YFL039C_ACT1_at              NaN            NaN            NaN
# PA0001_dnaA_at                    0.0            1.0            0.0
# PA0002_dnaN_at                    0.0            1.0            0.0
# PA0003_recF_at                    0.0            1.0            0.0
# PA0004_gyrB_at                    0.0            1.0            0.0
# PA0005_at                         1.0            1.0            0.0
# PA0006_at                         1.0            0.0            0.0
# PA0007_at                         0.0            1.0            0.0
# PA0008_glyS_at                    1.0            1.0            1.0
# PA0009_glyQ_at                    1.0            1.0            1.0
# PA0010_tag_at                     0.0            NaN            NaN
# PA0011_at                         0.0            0.0            0.0
# PA0012_at                         0.0            0.0            0.0
# PA0013_at                         0.0            1.0            0.0
# PA0014_at                         0.0            NaN            NaN
# PA0015_at                         0.0            1.0            0.0
# PA0016_trkA_at                    0.0            1.0            0.0
# ...                               ...            ...            ...
# ig_5991130_5992382_at             NaN            NaN            NaN
# ig_5992382_5991130_at             NaN            NaN            NaN
# ig_6090705_6092045_at             NaN            NaN            NaN
# ig_6092045_6090705_at             NaN            NaN            NaN
# ig_6125079_6125795_at             NaN            NaN            NaN
# ig_6125795_6125079_at             NaN            NaN            NaN
# ig_629884_630527_at               NaN            NaN            NaN
# ig_630527_629884_at               NaN            NaN            NaN
# ig_64729_65339_at                 NaN            NaN            NaN
# ig_65339_64729_at                 NaN            NaN            NaN
# ig_65479_66303_at                 NaN            NaN            NaN
# ig_66303_65479_at                 NaN            NaN            NaN
# ig_68616_69272_at                 NaN            NaN            NaN
# ig_69272_68616_at                 NaN            NaN            NaN
# ig_721556_727608_s_at             NaN            NaN            NaN
# ig_727608_721556_s_at             NaN            NaN            NaN
# ig_773696_774416_at               NaN            NaN            NaN
# ig_774416_773696_at               NaN            NaN            NaN
# ig_785174_785969_at               NaN            NaN            NaN
# ig_785969_785174_at               NaN            NaN            NaN
# ig_788253_789144_at               NaN            NaN            NaN
# ig_789144_788253_at               NaN            NaN            NaN
# ig_863300_864095_at               NaN            NaN            NaN
# ig_864095_863300_at               NaN            NaN            NaN
# ig_884172_884799_at               NaN            NaN            NaN
# ig_884799_884172_at               NaN            NaN            NaN
# ig_901046_901934_at               NaN            NaN            NaN
# ig_901934_901046_at               NaN            NaN            NaN
# ig_991198_991830_at               NaN            NaN            NaN
# ig_991830_991198_at               NaN            NaN            NaN
#
#                         experiment_67  experiment_68  experiment_69  \
# ProbeID
# AFFX-Athal_GAPDH_at               NaN            NaN            NaN
# AFFX-Athal_actin_at               NaN            NaN            NaN
# AFFX-Athal_ubq_at                 NaN            NaN            NaN
# AFFX-Bsubtilis_dapB_at            NaN            NaN            NaN
# AFFX-Bsubtilis_lys_at             NaN            NaN            NaN
# AFFX-Bsubtilis_pheB_at            NaN            NaN            NaN
# AFFX-Bsubtilis_thrC_at            NaN            NaN            NaN
# AFFX-Bsubtilis_trpD_at            NaN            NaN            NaN
# AFFX-YEL002C_WPB1_at              NaN            NaN            NaN
# AFFX-YEL018W_at                   NaN            NaN            NaN
# AFFX-YEL024W_RIP1_at              NaN            NaN            NaN
# AFFX-YER022W_SRB4_at              NaN            NaN            NaN
# AFFX-YER148W_SPT15_at             NaN            NaN            NaN
# AFFX-YFL039C_ACT1_at              NaN            NaN            NaN
# PA0001_dnaA_at                    0.0            0.0            0.0
# PA0002_dnaN_at                    0.0            0.0            0.0
# PA0003_recF_at                    0.0            0.0            0.0
# PA0004_gyrB_at                    0.0            0.0            0.0
# PA0005_at                         0.0            0.0            0.0
# PA0006_at                         0.0            0.0            0.0
# PA0007_at                         0.0            0.0            0.0
# PA0008_glyS_at                    0.0            0.0            0.0
# PA0009_glyQ_at                    0.0            0.0            0.0
# PA0010_tag_at                     0.0            0.0            0.0
# PA0011_at                         0.0            0.0            0.0
# PA0012_at                         0.0            0.0            0.0
# PA0013_at                         0.0            0.0            0.0
# PA0014_at                         0.0            0.0            0.0
# PA0015_at                         0.0            0.0            0.0
# PA0016_trkA_at                    0.0            0.0            0.0
# ...                               ...            ...            ...
# ig_5991130_5992382_at             NaN            NaN            NaN
# ig_5992382_5991130_at             NaN            NaN            NaN
# ig_6090705_6092045_at             NaN            NaN            NaN
# ig_6092045_6090705_at             NaN            NaN            NaN
# ig_6125079_6125795_at             NaN            NaN            NaN
# ig_6125795_6125079_at             NaN            NaN            NaN
# ig_629884_630527_at               NaN            NaN            NaN
# ig_630527_629884_at               NaN            NaN            NaN
# ig_64729_65339_at                 NaN            NaN            NaN
# ig_65339_64729_at                 NaN            NaN            NaN
# ig_65479_66303_at                 NaN            NaN            NaN
# ig_66303_65479_at                 NaN            NaN            NaN
# ig_68616_69272_at                 NaN            NaN            NaN
# ig_69272_68616_at                 NaN            NaN            NaN
# ig_721556_727608_s_at             NaN            NaN            NaN
# ig_727608_721556_s_at             NaN            NaN            NaN
# ig_773696_774416_at               NaN            NaN            NaN
# ig_774416_773696_at               NaN            NaN            NaN
# ig_785174_785969_at               NaN            NaN            NaN
# ig_785969_785174_at               NaN            NaN            NaN
# ig_788253_789144_at               NaN            NaN            NaN
# ig_789144_788253_at               NaN            NaN            NaN
# ig_863300_864095_at               NaN            NaN            NaN
# ig_864095_863300_at               NaN            NaN            NaN
# ig_884172_884799_at               NaN            NaN            NaN
# ig_884799_884172_at               NaN            NaN            NaN
# ig_901046_901934_at               NaN            NaN            NaN
# ig_901934_901046_at               NaN            NaN            NaN
# ig_991198_991830_at               NaN            NaN            NaN
# ig_991830_991198_at               NaN            NaN            NaN
#
#                         experiment_70  experiment_71  experiment_72
# ProbeID
# AFFX-Athal_GAPDH_at               NaN            NaN            NaN
# AFFX-Athal_actin_at               NaN            NaN            NaN
# AFFX-Athal_ubq_at                 NaN            NaN            NaN
# AFFX-Bsubtilis_dapB_at            NaN            NaN            NaN
# AFFX-Bsubtilis_lys_at             NaN            NaN            NaN
# AFFX-Bsubtilis_pheB_at            NaN            NaN            NaN
# AFFX-Bsubtilis_thrC_at            NaN            NaN            NaN
# AFFX-Bsubtilis_trpD_at            NaN            NaN            NaN
# AFFX-YEL002C_WPB1_at              NaN            NaN            NaN
# AFFX-YEL018W_at                   NaN            NaN            NaN
# AFFX-YEL024W_RIP1_at              NaN            NaN            NaN
# AFFX-YER022W_SRB4_at              NaN            NaN            NaN
# AFFX-YER148W_SPT15_at             NaN            NaN            NaN
# AFFX-YFL039C_ACT1_at              NaN            NaN            NaN
# PA0001_dnaA_at                    0.0            0.0            1.0
# PA0002_dnaN_at                    0.0            0.0            0.0
# PA0003_recF_at                    0.0            0.0            1.0
# PA0004_gyrB_at                    0.0            0.0            1.0
# PA0005_at                         0.0            0.0            0.0
# PA0006_at                         0.0            0.0            0.0
# PA0007_at                         0.0            0.0            1.0
# PA0008_glyS_at                    0.0            0.0            1.0
# PA0009_glyQ_at                    0.0            0.0            1.0
# PA0010_tag_at                     0.0            0.0            0.0
# PA0011_at                         0.0            0.0            0.0
# PA0012_at                         0.0            0.0            0.0
# PA0013_at                         0.0            0.0            0.0
# PA0014_at                         0.0            NaN            NaN
# PA0015_at                         0.0            0.0            0.0
# PA0016_trkA_at                    0.0            0.0            0.0
# ...                               ...            ...            ...
# ig_5991130_5992382_at             NaN            NaN            NaN
# ig_5992382_5991130_at             NaN            NaN            NaN
# ig_6090705_6092045_at             NaN            NaN            NaN
# ig_6092045_6090705_at             NaN            NaN            NaN
# ig_6125079_6125795_at             NaN            NaN            NaN
# ig_6125795_6125079_at             NaN            NaN            NaN
# ig_629884_630527_at               NaN            NaN            NaN
# ig_630527_629884_at               NaN            NaN            NaN
# ig_64729_65339_at                 NaN            NaN            NaN
# ig_65339_64729_at                 NaN            NaN            NaN
# ig_65479_66303_at                 NaN            NaN            NaN
# ig_66303_65479_at                 NaN            NaN            NaN
# ig_68616_69272_at                 NaN            NaN            NaN
# ig_69272_68616_at                 NaN            NaN            NaN
# ig_721556_727608_s_at             NaN            NaN            NaN
# ig_727608_721556_s_at             NaN            NaN            NaN
# ig_773696_774416_at               NaN            NaN            NaN
# ig_774416_773696_at               NaN            NaN            NaN
# ig_785174_785969_at               NaN            NaN            NaN
# ig_785969_785174_at               NaN            NaN            NaN
# ig_788253_789144_at               NaN            NaN            NaN
# ig_789144_788253_at               NaN            NaN            NaN
# ig_863300_864095_at               NaN            NaN            NaN
# ig_864095_863300_at               NaN            NaN            NaN
# ig_884172_884799_at               NaN            NaN            NaN
# ig_884799_884172_at               NaN            NaN            NaN
# ig_901046_901934_at               NaN            NaN            NaN
# ig_901934_901046_at               NaN            NaN            NaN
# ig_991198_991830_at               NaN            NaN            NaN
# ig_991830_991198_at               NaN            NaN            NaN
#
# [5900 rows x 73 columns]

# %%
# Map `ProbeID` to `IntergenicSpotID` that contains PA#### IDs
example_reference_df = ro.conversion.rpy2py(reference_Robject[0])
example_reference_df.set_index("ProbeID", inplace=True)

merged_df = pd.merge(
    reference_stats_df, example_reference_df, left_index=True, right_index=True
)

# Get relevant columns (`IntergenicSpotID` and `experiment_*`)
experiment_cols = [col for col in merged_df.columns if "experiment_" in col]
merged_df = merged_df[experiment_cols]

merged_df.sum(axis=1)
# Out:
# ProbeID
# AFFX-Athal_GAPDH_at        6.0
# AFFX-Athal_actin_at        6.0
# AFFX-Athal_ubq_at          7.0
# AFFX-Bsubtilis_dapB_at    11.0
# AFFX-Bsubtilis_lys_at     12.0
# AFFX-Bsubtilis_pheB_at    13.0
# AFFX-Bsubtilis_thrC_at    13.0
# AFFX-Bsubtilis_trpD_at    10.0
# AFFX-YEL002C_WPB1_at       8.0
# AFFX-YEL018W_at            9.0
# AFFX-YEL024W_RIP1_at       9.0
# AFFX-YER022W_SRB4_at       7.0
# AFFX-YER148W_SPT15_at     11.0
# AFFX-YFL039C_ACT1_at       7.0
# PA0001_dnaA_at            23.0
# PA0002_dnaN_at            16.0
# PA0003_recF_at            22.0
# PA0004_gyrB_at            17.0
# PA0005_at                 16.0
# PA0006_at                 13.0
# PA0007_at                 22.0
# PA0008_glyS_at            22.0
# PA0009_glyQ_at            24.0
# PA0010_tag_at              7.0
# PA0011_at                 11.0
# PA0012_at                 12.0
# PA0013_at                 12.0
# PA0014_at                  9.0
# PA0015_at                 13.0
# PA0016_trkA_at            13.0
#                           ...
# ig_5991130_5992382_at     13.0
# ig_5992382_5991130_at      9.0
# ig_6090705_6092045_at     10.0
# ig_6092045_6090705_at     10.0
# ig_6125079_6125795_at     14.0
# ig_6125795_6125079_at     16.0
# ig_629884_630527_at       11.0
# ig_630527_629884_at       16.0
# ig_64729_65339_at         10.0
# ig_65339_64729_at         13.0
# ig_65479_66303_at          8.0
# ig_66303_65479_at         11.0
# ig_68616_69272_at          9.0
# ig_69272_68616_at          8.0
# ig_721556_727608_s_at     19.0
# ig_727608_721556_s_at     11.0
# ig_773696_774416_at       12.0
# ig_774416_773696_at        6.0
# ig_785174_785969_at        9.0
# ig_785969_785174_at       11.0
# ig_788253_789144_at       13.0
# ig_789144_788253_at       11.0
# ig_863300_864095_at       14.0
# ig_864095_863300_at       12.0
# ig_884172_884799_at       17.0
# ig_884799_884172_at       11.0
# ig_901046_901934_at        9.0
# ig_901934_901046_at        8.0
# ig_991198_991830_at       20.0
# ig_991830_991198_at        7.0
# Length: 5900, dtype: float64

# %%
# Aggregate to get ranking of genes
merged_df["prop DEGs"] = merged_df.sum(axis=1) / num_experiments

# %%
# Extract PA#### ids from `ProbeID`
# This will be used to compare against SOPHIE ranked genes
pao1_ids = [str_ls[0] for str_ls in merged_df.index.str.split("_")]
merged_df["gene id"] = pao1_ids

# %%
# Save file
# Here are the names that we will use for the comparison in notebook 2_identify_generic_genes_pathways.ipynb
# DE_prior_filename = output_filename
# ref_gene_col = "gene id"
# ref_rank_col = "prop DEGs"
merged_df.to_csv("GAPE_proportions.txt", sep="\t")
